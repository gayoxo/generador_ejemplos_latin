# %%
import pandas as pd

# %%
path_file_v = 'data/verbos.xlsx'
path_file_s = 'data/sustantivos.xlsx'
hoja = 'Hoja1'


df_v = pd.read_excel(path_file_v, sheet_name=hoja)
df_s = pd.read_excel(path_file_s, sheet_name=hoja)

# Organizamos la información de la tabla de verbos en listas
ve = df_v[['VERBOS']].to_string(header=False, index=False)
verbos = []
b = ve.split('\n')
for word in b:
    word = word.split()
    verbos.append(word[0][:-1])

# %%
verbos
# Out:
# ['accipio',
#  'accipio2',
#  'accuso',
#  'addo',
#  'admoneo',
#  'admoneo2',
#  'affero',
#  'amo',
#  'antepono',
#  'attribuo',
#  'confero',
#  'dico',
#  'dico2',
#  'dico3',
#  'do',
#  'doceo',
#  'dono',
#  'habeo',
#  'habito',
#  'impertio',
#  'iniungo',
#  'interrogo',
#  'mitto',
#  'monstro',
#  'moveo',
#  'neglego',
#  'neglego2',
#  'nego',
#  'nego2',
#  'nescio',
#  'noceo',
#  'nosco',
#  'nosco2',
#  'nuntio',
#  'nuntio2',
#  'nutrio',
#  'pendeo',
#  'obeo',
#  'obeo2',
#  'obicio',
#  'obicio2',
#  'obiurgo',
#  'obiurgo2',
#  'obtego',
#  'occupo',
#  'occupo2',
#  'occurro',
#  'occurro2',
#  'offundo2',
#  'omitto',
#  'omitto2',
#  'onero',
#  'operio',
#  'operio2',
#  'opinor',
#  'opinor2',
#  'oppugno',
#  'oppugno2',
#  'ostendo',
#  'ostendo2',
#  'paciscor',
#  'paciscor2',
#  'paeniteo',
#  'paeniteo2',
#  'pango',
#  'pango2',
#  'pario2',
#  'pateo',
#  'paveo',
#  'paveo2',
#  'pecco',
#  'pecco2',
#  'pendeo',
#  'percello',
#  'percello2',
#  'percurro',
#  'percurro2',
#  'perduco',
#  'perduco2',
#  'pereo',
#  'pereo2',
#  'perfugio',
#  'permitto',
#  'permitto2',
#  'persevero',
#  'persevero2',
#  'peto',
#  'peto2',
#  'placeo',
#  'placeo2',
#  'ploro',
#  'ploro2',
#  'pono',
#  'possum',
#  'possum2',
#  'praefero',
#  'praeficio',
#  'praepondero',
#  'praepondero2',
#  'praesto',
#  'praesto2',
#  'praesumo',
#  'praesumo2',
#  'premo',
#  'premo2',
#  'probo',
#  'probo2',
#  'produco',
#  'profugio',
#  'profugio2',
#  'pungo',
#  'pungo2',
#  'puto',
#  'puto2',
#  'quaero',
#  'quaero2',
#  'resideo',
#  'sum2',
#  'video',
#  'voco',
#  'oro']

# %%
ve = df_v['VERBOS'].to_list()

# %%
ve
# Out:
# ['accipio,  S1 <b>oir, percibir, observar algo </b> accipio, -is, -ere, -cepi, -ceptum (5ª)',
#  'accipio2,  S2 <b>recibir, aceptar algo de alguien</b> accipio, -is, -ere, -cepi, -ceptum (5ª)',
#  'accuso,  S1 <b>acusar a alguien de algo</b>       <hr/>  \naccuso, -as, -are, -avi, -atum (1ª)',
#  'addo,  S1 <b>añadir algo a alguien / a algo </b>       <hr/>  \naddo, -is, -ere, -didi, -ditum (3ª)',
#  'admoneo,  S1 <b>recordarle  algo a alguien</b> admoneo, -es, -ere, -ui, -itum (2ª)',
#  'admoneo2,  S2<b>advertir a alguien de algo</b>  admoneo, -es, -ere, -ui, -itum (2ª)',
#  'affero,  S1 <b>llevarle algo alguien</b>      <hr/>\naffero, affers, afferre, attuli, allatum (3ª)',
#  'amo,  S1 <b>amar algo o a alguien, gustarle algo a alguien</b>       <hr/>  \namo, -as, -are, -avi, -atum (1ª)',
#  'antepono,  S1 <b>anteponer algo/a alguien a algo/a alguien</b>      <hr/>  \nantepono, -is, -ere, -sui (-sivi), -situm (3ª)',
#  'attribuo,  S1 <b>atribuirle, asignarle algo a alguien</b>      <hr/>\nattribuo, -ui, -ere, -ui, -utum (3ª)',
#  'confero,  S1 <b>pagarle algo a alguien</b>     <hr/>  \nconfero, fers, -erre, tuli, latum (3ª)',
#  'dico,  S1 <b>decirle algo a alguien</b>       <hr/>\ndico, -is, -ere, dixi, dictum (3ª)',
#  'dico2,  S2 <b>pronunciar</b>  dico, -is, -ere, dixi, dictum (3ª)',
#  'dico3,  S1 <b>dedicarle, consagrarle algo a alguien</b> <hr/>  \ndico, -as, -are, -avi, -atum (1ª)',
#  'do,  S1 <b>darle algo a alguien</b>      <hr/>  \ndo, -as, -are, dedi, datum (1ª)',
#  'doceo,  S1 <b>enseñarle (docencia) algo a alguien</b>       <hr/>  \ndoceo, -es, -ere, -ui, -tum (2ª)',
#  'dono,  S1 <b>regalarle algo a alguien</b>       <hr/>  \ndono, -as, -are, -avi, -atum (1ª)',
#  'habeo,  S1 <b>tener</b> habeo, -es, -ere, -bui, -itum (2ª)',
#  'habito,  S1 <b>habitar en (ubicación) </b> habito, -as, -are, -avi, -atum (1ª)',
#  'impertio,  S1 <b>otorgarle algo a alguien</b>       <hr/>  \nimpertio, -is, -ire, -ivi (-ii), -itum (4ª)',
#  'iniungo,  S1 <b>imponerle algo a alguien</b>     <hr/>  \niniungo, -is, -ere, -iunxi, -iunctum (3ª)',
#  'interrogo,  S1 <b>preguntarle a alguien sobre algo</b>       <hr/>  \ninterrogo, as, are, avi, atum (1ª)',
#  'mitto,  S1 <b>enviarle algo a alguien</b>      <hr/>  \nmitto, -is, -ere, misi, missum (3ª)',
#  'monstro,  S1 <b>mostrar algo a alguien</b>       <hr/>  \nmonstro, -as, -are, -avi, -atum (1ª)',
#  'moveo,  S2 <b>separar, alejar a alguien de algo/de alguien</b> moveo, -es, -ere, movi, motum (2ª)',
#  'neglego,  S1 <b>descuidar algo</b> neglego, -is, -ere, -exi, -extum (3ª)',
#  'neglego2,  S2 <b>no preocuparse por alguien</b> neglego, -is, -ere, -exi, -extum (3ª)',
#  'nego,  S1 <b>decir que no</b> nego, -as, -are, -avi, -atum (1ª)',
#  'nego2,  S2 <b>denegarle algo a alguien</b> nego, -as, -are, -avi, -atum (1ª)',
#  'nescio,  S1 <b>no saber</b> nescio, -is, -ire, -ivi (-ii), -itum (4ª)',
#  'noceo,  S1 <b>perjudicar a alguien</b>  noceo, -es, -ere, -ui, -itum (2ª)',
#  'nosco,  S1 <b>conocer a alguien</b>  nosco, -is, -ere, novi, notum (3ª)',
#  'nosco2, S2 <b>saber, conocer algo</b>  nosco, -is, -ere, novi, notum (3ª)',
#  'nuntio,  S1 <b>anunciarle algo a alguien</b>  nuntio, -as,-are, -avi, -atum (1ª)',
#  'nuntio2, S2 <b>dar la orden de, ordenar que</b> nuntio, -as,-are, -avi, -atum (1ª)',
#  'nutrio,  S1 <b>alimentar a alguien/algo</b>  nutrio, -is, -ire, -ivi (-ii), -itum (4ª)',
#  'pendeo,  S1 <b>estar colgado de</b>  pendeo, -es, -ere, pependi, - (2ª)',
#  'obeo,  S1 <b>afrontar algo</b>  obeo, -is, -ire, -ii (-ivi), -itum (4ª)',
#  'obeo2, S2 <b>salir al encuentro de alguien</b>  obeo, -is, -ire, -ii (-ivi), -itum (4ª)',
#  'obicio, S1 <b>arrojarle algo a alguien</b> obicio, -is, -ere, -ieci, -ectum (3ª)',
#  'obicio2, S2 <b>causarle algo a alguien</b> obicio, -is, -ere, -ieci, -ectum (3ª)',
#  'obiurgo,  S1 <b>reñir a alguien</b> obiurgo, -as, -are, -avi, -atum (1ª)',
#  'obiurgo2,  S2 <b>reñir/castigar a alguien por algo</b> obiurgo, -as, -are, -avi, -atum (1ª)',
#  'obtego, S1 <b>cubrir, ocultar algo o a alguien</b>     <hr/>  \nobtego, -is, -ere, -texi, -tectum (3ª)',
#  'occupo, S1 <b>apoderarse de algo, ocupar algo</b> occupo, -as, -are, -avi, -atum (1ª)',
#  'occupo2, S2 <b>anticiparse a alguien</b>  occupo, -as, -are, -avi, -atum (1ª)',
#  'occurro,  S1 <b>salir al encuentro de alguien</b> occurro, -is, -ere, -curri, -cursum (3ª)',
#  'occurro2,  S2 <b>afrontar algo</b> occurro, -is, -ere, -curri, -cursum (3ª)',
#  'offundo2, S2 <b>ofuscar, eclipsar a alguien</b> offundo, -is, -ere, -fudi, -fusum (3ª)',
#  'omitto,  S1 <b>dejar escapar algo</b>  omitto, -is, -ere, -misi, -missum (3ª)',
#  'omitto2, S2 <b>no hablar sobre algo</b> omitto, -is, -ere, -misi, -missum (3ª)',
#  'onero,  S2 <b>abrumar a agluien con algo</b>  onero, -as, -are, -avi, -atum (1ª)',
#  'operio, S1 <b>cubrir algo</b> operio, -is, -ire, -perui, -pertum (4ª)',
#  'operio2, S2 <b>disimular algo</b> operio, -is, -ire, -perui, -pertum (4ª)',
#  'opinor, S1 <b>tener una opinión sobre alguien / algo</b>  opinor, -ari, -atus sum (1ª)',
#  'opinor2, S2 <b>creer (absoluto)</b>   opinor, -ari, -atus sum (1ª)',
#  'oppugno, S1 <b>atacar (un lugar)</b> oppugno, -as, -are, -avi, -atum (1ª)',
#  'oppugno2, S2 <b>tentar a alguien con algo</b> oppugno, -as, -are, -avi, -atum (1ª)',
#  'ostendo,  S1 <b>mostrarle/enseñarle algo a alguien</b>  ostendo, -is, -ere, -tendi, -tensum (3ª)',
#  'ostendo2, S2 <b>prometer que</b> ostendo, -is, -ere, -tendi, -tensum (3ª)',
#  'paciscor, S1 <b>pactar con alguien algo</b>  paciscor, -eris, -i, pactus sum (3ª)',
#  'paciscor2, S2 <b>comprometerse a</b> paciscor, -eris, -i, pactus sum (3ª)',
#  'paeniteo, S1 <b>arrepentirse de algo</b>  paeniteo, -es, -ere, -ui, - (2ª)',
#  'paeniteo2, S2 <b>arrepentirse (absoluto)</b> paeniteo, -es, -ere, -ui, - (2ª)',
#  'pango, S1 <b>clavar, hundir algo</b> pango, -is, -ere, panxi (pegi o pepigi), pactum (3ª)',
#  'pango2, S2 <b>comprometerse a</b> pango, -is, -ere, panxi (pegi o pepigi), pactum (3ª)',
#  'pario2, S2 <b>adquirir algo</b> pario, -is, -ere, peperi, partum (3ª)',
#  'pateo,  S1 <b>estar abierto</b>  pateo, -es, -ere, -ui - (2ª)',
#  'paveo,  S1 <b>alguien se siente aterrado/atemorizado</b> paveo, es, ere, pavi, - (2ª)',
#  'paveo2,  S2 <b>alguien tiene miedo de alguien o de algo</b> paveo, es, ere, pavi, - (2ª)',
#  'pecco,  S1 <b>ofender a alguien</b>  pecco, -as, -are, -avi, -atum (1ª)',
#  'pecco2, S2 <b>equivocarse en algo</b> pecco, -as, -are, -avi, -atum (1ª)',
#  'pendeo,  S2 <b>pesar, valer algo (un numeral)</b> pendeo, -es, -ere, pependi, - (2ª)',
#  'percello,  S1 <b>derribar algo</b> percello, -is, -ere, perculi, perculsum (3ª)',
#  'percello2, S2 <b>herir a alguien</b> percello, -is, -ere, perculi, perculsum (3ª)',
#  'percurro,  S1 <b>correr</b>  percurro, -is, -ere, percurri, percursum (3ª)',
#  'percurro2, S2 <b>recorrer, atravesar corriendo algun sitio</b> percurro, -is, -ere, percurri, percursum (3ª)',
#  'perduco,  S1 <b>conducir a alguien hacia alguien /hacia algún sitio</b>  perduco, -is, -ere, perduxi, perductum (3ª)',
#  'perduco2,  S2 <b>construir algo</b> perduco, -is, -ere, perduxi, perductum (3ª)',
#  'pereo,  S1 <b>perecer</b>  pereo, -is, -ire, -ii, -itum (4ª)',
#  'pereo2,  S2 <b>desaparecer</b> pereo, -is, -ire, -ii, -itum (4ª)',
#  'perfugio,  S1 <b>huir hacia algún sitio</b> perfugio, -is, -ire, perfugi,- (3ª)',
#  'permitto,  S1 <b>confiarle algo a alguien</b>  permitto, -is, -ire, permisi, permissum (3ª)',
#  'permitto2, S2 <b>permitirle algo a alguien</b>  permitto, -is, -ire, permisi, permissum (3ª)',
#  'persevero,  S1 <b>perserverar en algo</b> persevero, -as, -are, -avi, -atum (1ª)',
#  'persevero2, S2 <b>empeñarse en, insistir en algo</b> persevero, -as, -are, -avi, -atum (1ª)',
#  'peto, S1 <b>pedir algo de alguien</b>      <hr/>\npeto, -is, -ere, -ii (-ivi), -itum (3ª)',
#  'peto2, S2 <b>atacar a alguien</b> peto, -is, -ere, -ii (-ivi), -itum (3ª)',
#  'placeo, S1 <b>deleitar a alguien</b>  placeo, -es, -ere, -ui, -itum (2ª)',
#  'placeo2, S2 <b>decidir algo</b> placeo, -es, -ere, -ui, -itum (2ª)',
#  'ploro,  S1 <b>lamentar algo</b> ploro, -as, -are, -avi, -atum (1ª)',
#  'ploro2,  S2 <b>llorar a alguien</b> ploro, -as, -are, -avi, -atum (1ª)',
#  'pono,  S1 <b>poner, colocar algo en un sitio</b>      <hr/>  \npono, -is, -ere, -sui (-sivi), -situm (3ª)',
#  'possum,  S1 <b>poder, ser capaz de</b> possum, potes, posse, potui, - (potis sum) irr.',
#  'possum2,  S2 <b>tener poder, fuerza</b> possum, potes, posse, potui, - (potis sum) irr.',
#  'praefero,  S1 <b>preferir</b>     <hr/>  praefero, fers, ferre, tuli, latum (3ª)',
#  'praeficio,  S1 <b>conceder a alguien el mando de algo </b>      <hr/>  \npraeficio, -is, -ficere, -feci, -fectum (3ª)',
#  'praepondero,  S1 <b>pesar, tener peso</b>  praepondero, -as, -are, -avi, -atum (1ª)',
#  'praepondero2,  S2 <b>inclinarse hacia</b> praepondero, -as, -are, -avi, -atum (1ª)',
#  'praesto,  S1 <b>aventajar a alguien</b> praesto, -as, -are, -stiti, -stitum (1ª)',
#  'praesto2,  S2 <b>superar a alguien en algo</b> praesto, -as, -are, -stiti, -stitum (1ª)',
#  'praesumo,  S1 <b>tomar / disfrutar anticipadamente</b>  praesumo, -is, -ere, -sumpsi, -sumptum (3ª)',
#  'praesumo2,  S2 <b>sopechar / tener por cierto que</b> praesumo, -is, -ere, -sumpsi, -sumptum (3ª)',
#  'premo,  S1 <b>apretar algo</b> premo, -is, -ere, pressi, pressum (3ª)',
#  'premo2, S2 <b>matar a alguien/algo</b> premo, -is, -ere, pressi, pressum (3ª)',
#  'probo,  S1 <b>probar algo</b> probo, -as, -are, -avi, -atum (1ª)',
#  'probo2,  S2 <b>probar (la calidad), inspeccionar algo </b> probo, -as, -are, -avi, -atum (1ª)',
#  'produco,  S1 <b>hacer avanzar a alguien/algo</b>  produco, -is, -ere, -duxi, -ductum (3ª)',
#  'profugio,  S1 <b>refugiarse en/junto a</b> profugio, -is, -ere, -fugi, - (3ª)',
#  'profugio2, S2 <b>escaparse de</b> profugio, -is, -ere, -fugi, - (3ª)',
#  'pungo,  S1 <b>punzar, pinchar algo/a alguien</b>  pungo, -is, -ere, pupungi, punctum (3ª)',
#  'pungo2, S2 <b>atormentar, mortificar a alguien</b> pungo, -is, -ere, pupungi, punctum (3ª)',
#  'puto, S1 <b>lavar, limpiar algo</b>  puto, -as, -are, -avi, -atum (1ª)',
#  'puto2, S2 <b>creer algo / en algo</b> puto, -as, -are, -avi, -atum (1ª)',
#  'quaero,  S1 <b>preguntar algo a alguien</b>  quaero, -is, -ere, -sivi (-sii), -situm (3ª)',
#  'quaero2, S2 <b>buscar algo / a alguien</b> quaero, -is, -ere, -sivi (-sii), -situm (3ª)',
#  'resideo,  S1 <b>residir en (ubicación)</b> resideo, -es, -ere, -sedi, -sessum (2ª)',
#  'sum2, S2 <b>estar (en un sitio)</b> sum, es, esse, fui',
#  'video,  S1 <b>ver algo o a alguien</b>  video, -es, -ere, vidi, visum (2ª)',
#  'voco,  S1 <b>llamar (intenter capatar la atención) a alguien / a un animal</b> voco, -as, -are, -avi, -atum (1ª)',
#  'oro,  S1 <b>rogarle algo a alguien</b>     <hr/>  \noro, -as, -are, -avi, -atum (1ª)']

# %%
verb = df_v['VERBOS'].to_list()
for word in verb[:20]:

    print(word.split(',')[0])
# Out:
# accipio
# accipio2
# accuso
# addo
# admoneo
# admoneo2
# affero
# amo
# antepono
# attribuo
# confero
# dico
# dico2
# dico3
# do
# doceo
# dono
# habeo
# habito
# impertio
